# %%
# Cell 1: Environment Setup and Imports
# %matplotlib widget

import matplotlib.pyplot as plt

from opym import PSFExtractor, PSFAverager, DeconvolutionViewer

# %%
# Cell 2: Initialize and Run the Extractor
plt.close("all")  # Clears any existing hidden plots to prevent memory leaks

extractor = PSFExtractor()
extractor.show()

# %%
# Cell 3: Initialize and Run the Averager
plt.close("all")  # Clears any existing hidden plots to prevent memory leaks

averager = PSFAverager()
averager.show()

# %%
# Cell 4: Initialize and Run the Viewer
plt.close("all")

viewer = DeconvolutionViewer()
viewer.show()
